# %% [markdown]
# # アソシエーション分析

# %% [markdown]
# ### Apriori

# %% [markdown]
# ## データ読み込み

# %%
# -*- coding: utf-8 -*-
import pandas as pd

# %%
df = pd.read_csv('../data/Apriori/groceries.csv')
df
# Out:
#     cardid          goods
# 0    39808      freshmeat
# 1    39808          dairy
# 2    39808  confectionery
# 3    67362      freshmeat
# 4    67362  confectionery
# 5    10872      cannedveg
# 6    10872     frozenmeal
# 7    10872           beer
# 8    10872           fish
# 9    28935       fruitveg
# 10   28935     frozenmeal
# 11   41792       fruitveg
# 12   41792           fish

# %% [markdown]
# userとitemの数

# %%
# usersの種類
users = sorted(df['cardid'].unique())
# itemの種類
items = sorted(df['goods'].unique())

print(f'usersの種類数：{len(users)}\nitemsの種類数：{len(items)}')
# Out:
# usersの種類数：5
# itemsの種類数：8

# %% [markdown]
# ## 前処理

# %% [markdown]
# ### データを「（ユーザが買った雑貨の）リストのリスト」という形式に変換する

# %%
def items_to_list(data, user_id):
    """あるユーザが買った雑貨を一つのリストに変換します.
    
    Args:
        data (DataFrame): ユーザーが雑貨を買ったデータ
        user_id (str)： ユーザーID

    Returns:
        (list): あるユーザ（ユーザーID）が買った雑貨のリスト.

    """
    item_list = data.loc[data['cardid']==user_id]['goods'].tolist()
    return item_list

# %%
# 全ユーザに対して各自の雑貨リストを計算して、「（ユーザが買った雑貨の）リストのリスト」を作成する

from functools import partial
# 訓練データ
func = partial(items_to_list, df)
item_list_list = list(map(func, users))
item_list_list
# Out:
# [['cannedveg', 'frozenmeal', 'beer', 'fish'],
#  ['fruitveg', 'frozenmeal'],
#  ['freshmeat', 'dairy', 'confectionery'],
#  ['fruitveg', 'fish'],
#  ['freshmeat', 'confectionery']]

# %% [markdown]
# ## モデリング

# %% [markdown]
# ### mlxtend パッケージを利用する

# %%
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori

te = TransactionEncoder()

# 「（ユーザが買った雑貨の）リストのリスト」を「sparse format」に変換する
te_ary = te.fit(item_list_list).transform(item_list_list)
item_sparse = pd.DataFrame(te_ary, columns=te.columns_)

# %%
# 頻出アイテム集合の検出
# supportが0.2以下のアイテムを削除する場合
frequent_itemsets = apriori(item_sparse, min_support=0.2, use_colnames=True)
frequent_itemsets.head()
# Out:
#    support         itemsets
# 0      0.2           (beer)
# 1      0.2      (cannedveg)
# 2      0.4  (confectionery)
# 3      0.2          (dairy)
# 4      0.4           (fish)

# %%
#相関ルールの検出

from mlxtend.frequent_patterns import association_rules
# confidenceが0.4以下のルールを削除する場合
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.4)

# %%
# 検出されたルールをさらに絞る
# 条件１：lift値が2以上
# 条件2：support値が0.2以上
rules_final = rules[(rules['lift']>=2) & (rules['support']>=0.2)]
rules_final
# Out:
#                       antecedents                    consequents  \
# 0                          (beer)                    (cannedveg)
# 1                     (cannedveg)                         (beer)
# 2                          (beer)                         (fish)
# 3                          (fish)                         (beer)
# 4                          (beer)                   (frozenmeal)
# 5                    (frozenmeal)                         (beer)
# 6                     (cannedveg)                         (fish)
# 7                          (fish)                    (cannedveg)
# 8                     (cannedveg)                   (frozenmeal)
# 9                    (frozenmeal)                    (cannedveg)
# 10                        (dairy)                (confectionery)
# 11                (confectionery)                        (dairy)
# 12                (confectionery)                    (freshmeat)
# 13                    (freshmeat)                (confectionery)
# 14                        (dairy)                    (freshmeat)
# 15                    (freshmeat)                        (dairy)
# 22              (beer, cannedveg)                         (fish)
# 23                   (beer, fish)                    (cannedveg)
# 24              (cannedveg, fish)                         (beer)
# 25                         (beer)              (cannedveg, fish)
# 26                    (cannedveg)                   (beer, fish)
# 27                         (fish)              (beer, cannedveg)
# 28              (beer, cannedveg)                   (frozenmeal)
# 29             (beer, frozenmeal)                    (cannedveg)
# 30        (cannedveg, frozenmeal)                         (beer)
# 31                         (beer)        (cannedveg, frozenmeal)
# 32                    (cannedveg)             (beer, frozenmeal)
# 33                   (frozenmeal)              (beer, cannedveg)
# 34             (beer, frozenmeal)                         (fish)
# 35                   (beer, fish)                   (frozenmeal)
# 36             (fish, frozenmeal)                         (beer)
# 37                         (beer)             (fish, frozenmeal)
# 38                   (frozenmeal)                   (beer, fish)
# 39                         (fish)             (beer, frozenmeal)
# 40        (cannedveg, frozenmeal)                         (fish)
# 41              (cannedveg, fish)                   (frozenmeal)
# 42             (fish, frozenmeal)                    (cannedveg)
# 43                    (cannedveg)             (fish, frozenmeal)
# 44                   (frozenmeal)              (cannedveg, fish)
# 45                         (fish)        (cannedveg, frozenmeal)
# 46         (dairy, confectionery)                    (freshmeat)
# 47             (dairy, freshmeat)                (confectionery)
# 48     (confectionery, freshmeat)                        (dairy)
# 49                        (dairy)     (confectionery, freshmeat)
# 50                (confectionery)             (dairy, freshmeat)
# 51                    (freshmeat)         (dairy, confectionery)
# 52  (beer, cannedveg, frozenmeal)                         (fish)
# 53        (beer, cannedveg, fish)                   (frozenmeal)
# 54       (beer, frozenmeal, fish)                    (cannedveg)
# 55  (cannedveg, frozenmeal, fish)                         (beer)
# 56              (beer, cannedveg)             (fish, frozenmeal)
# 57             (beer, frozenmeal)              (cannedveg, fish)
# 58                   (beer, fish)        (cannedveg, frozenmeal)
# 59        (cannedveg, frozenmeal)                   (beer, fish)
# 60              (cannedveg, fish)             (beer, frozenmeal)
# 61             (fish, frozenmeal)              (beer, cannedveg)
# 62                         (beer)  (cannedveg, frozenmeal, fish)
# 63                    (cannedveg)       (beer, frozenmeal, fish)
# 64                   (frozenmeal)        (beer, cannedveg, fish)
# 65                         (fish)  (beer, cannedveg, frozenmeal)
#
#     antecedent support  consequent support  support  confidence  lift  \
# 0                  0.2                 0.2      0.2         1.0   5.0
# 1                  0.2                 0.2      0.2         1.0   5.0
# 2                  0.2                 0.4      0.2         1.0   2.5
# 3                  0.4                 0.2      0.2         0.5   2.5
# 4                  0.2                 0.4      0.2         1.0   2.5
# 5                  0.4                 0.2      0.2         0.5   2.5
# 6                  0.2                 0.4      0.2         1.0   2.5
# 7                  0.4                 0.2      0.2         0.5   2.5
# 8                  0.2                 0.4      0.2         1.0   2.5
# 9                  0.4                 0.2      0.2         0.5   2.5
# 10                 0.2                 0.4      0.2         1.0   2.5
# 11                 0.4                 0.2      0.2         0.5   2.5
# 12                 0.4                 0.4      0.4         1.0   2.5
# 13                 0.4                 0.4      0.4         1.0   2.5
# 14                 0.2                 0.4      0.2         1.0   2.5
# 15                 0.4                 0.2      0.2         0.5   2.5
# 22                 0.2                 0.4      0.2         1.0   2.5
# 23                 0.2                 0.2      0.2         1.0   5.0
# 24                 0.2                 0.2      0.2         1.0   5.0
# 25                 0.2                 0.2      0.2         1.0   5.0
# 26                 0.2                 0.2      0.2         1.0   5.0
# 27                 0.4                 0.2      0.2         0.5   2.5
# 28                 0.2                 0.4      0.2         1.0   2.5
# 29                 0.2                 0.2      0.2         1.0   5.0
# 30                 0.2                 0.2      0.2         1.0   5.0
# 31                 0.2                 0.2      0.2         1.0   5.0
# 32                 0.2                 0.2      0.2         1.0   5.0
# 33                 0.4                 0.2      0.2         0.5   2.5
# 34                 0.2                 0.4      0.2         1.0   2.5
# 35                 0.2                 0.4      0.2         1.0   2.5
# 36                 0.2                 0.2      0.2         1.0   5.0
# 37                 0.2                 0.2      0.2         1.0   5.0
# 38                 0.4                 0.2      0.2         0.5   2.5
# 39                 0.4                 0.2      0.2         0.5   2.5
# 40                 0.2                 0.4      0.2         1.0   2.5
# 41                 0.2                 0.4      0.2         1.0   2.5
# 42                 0.2                 0.2      0.2         1.0   5.0
# 43                 0.2                 0.2      0.2         1.0   5.0
# 44                 0.4                 0.2      0.2         0.5   2.5
# 45                 0.4                 0.2      0.2         0.5   2.5
# 46                 0.2                 0.4      0.2         1.0   2.5
# 47                 0.2                 0.4      0.2         1.0   2.5
# 48                 0.4                 0.2      0.2         0.5   2.5
# 49                 0.2                 0.4      0.2         1.0   2.5
# 50                 0.4                 0.2      0.2         0.5   2.5
# 51                 0.4                 0.2      0.2         0.5   2.5
# 52                 0.2                 0.4      0.2         1.0   2.5
# 53                 0.2                 0.4      0.2         1.0   2.5
# 54                 0.2                 0.2      0.2         1.0   5.0
# 55                 0.2                 0.2      0.2         1.0   5.0
# 56                 0.2                 0.2      0.2         1.0   5.0
# 57                 0.2                 0.2      0.2         1.0   5.0
# 58                 0.2                 0.2      0.2         1.0   5.0
# 59                 0.2                 0.2      0.2         1.0   5.0
# 60                 0.2                 0.2      0.2         1.0   5.0
# 61                 0.2                 0.2      0.2         1.0   5.0
# 62                 0.2                 0.2      0.2         1.0   5.0
# 63                 0.2                 0.2      0.2         1.0   5.0
# 64                 0.4                 0.2      0.2         0.5   2.5
# 65                 0.4                 0.2      0.2         0.5   2.5
#
#     leverage  conviction
# 0       0.16         inf
# 1       0.16         inf
# 2       0.12         inf
# 3       0.12    1.600000
# 4       0.12         inf
# 5       0.12    1.600000
# 6       0.12         inf
# 7       0.12    1.600000
# 8       0.12         inf
# 9       0.12    1.600000
# 10      0.12         inf
# 11      0.12    1.600000
# 12      0.24         inf
# 13      0.24         inf
# 14      0.12         inf
# 15      0.12    1.600000
# 22      0.12         inf
# 23      0.16         inf
# 24      0.16         inf
# 25      0.16         inf
# 26      0.16         inf
# 27      0.12    1.600000
# 28      0.12         inf
# 29      0.16         inf
# 30      0.16         inf
# 31      0.16         inf
# 32      0.16         inf
# 33      0.12    1.600000
# 34      0.12         inf
# 35      0.12         inf
# 36      0.16         inf
# 37      0.16         inf
# 38      0.12    1.600000
# 39      0.12    1.600000
# 40      0.12         inf
# 41      0.12         inf
# 42      0.16         inf
# 43      0.16         inf
# 44      0.12    1.600000
# 45      0.12    1.600000
# 46      0.12         inf
# 47      0.12         inf
# 48      0.12    1.600000
# 49      0.12         inf
# 50      0.12    1.600000
# 51      0.12    1.600000
# 52      0.12         inf
# 53      0.12         inf
# 54      0.16         inf
# 55      0.16         inf
# 56      0.16         inf
# 57      0.16         inf
# 58      0.16         inf
# 59      0.16         inf
# 60      0.16         inf
# 61      0.16         inf
# 62      0.16         inf
# 63      0.16         inf
# 64      0.12    1.600000
# 65      0.12    1.600000

# %%
# ルールを出力する
def print_rule(rule_index):
    """特定行のルールを出力する.
    
    Args:
        rule_index (int): 何行目のルールを出力するか.

    Returns:
        (None)

    """
    # antecedentsを取得
    items1 = rules_final.iloc[rule_index]['antecedents']
    st1 = ''
    for i in items1:
        st1 += f'「{i}」、'
    st1 = st1[:-1]
    # consequentsを取得
    items2 = list(rules_final.iloc[rule_index]['consequents'])
    st2 = ''
    for i in items2:
        st2 += f'「{i}」、'
    st2 = st2[:-1]

    print(f'相関ルール１： \n\t{st1} を買った人が　{st2} を買う')
    print(f'指標結果：\n\tSupport: {rules_final.iloc[rule_index]["support"]:.3}\n\tConfidence: {rules_final.iloc[rule_index]["confidence"]:.3}\n\tLift　: {rules_final.iloc[rule_index]["lift"]:.3}')
    print(f'\tLeverage: {rules_final.iloc[rule_index]["leverage"]:.3}\n\tConviction: {rules_final.iloc[rule_index]["conviction"]:.3}')

# %%
# １行目のルールを確認する
print_rule(rule_index=0)
# Out:
# 相関ルール１：
# 	「beer」 を買った人が　「cannedveg」 を買う
# 指標結果：
# 	Support: 0.2
# 	Confidence: 1.0
# 	Lift　: 5.0
# 	Leverage: 0.16
# 	Conviction: inf

# %%
# 3行目のルールを確認する
print_rule(rule_index=2)
# Out:
# 相関ルール１：
# 	「beer」 を買った人が　「fish」 を買う
# 指標結果：
# 	Support: 0.2
# 	Confidence: 1.0
# 	Lift　: 2.5
# 	Leverage: 0.12
# 	Conviction: inf

# %% [markdown]
# ### 推薦項目のリストを作成する

# %%
from functools import reduce 
def predict(users, item_list_list):
    """推薦項目のリストを作成する.
    
    Args:
        user_id (str): ユーザーID.
        item_list (list): あるユーザーが買った雑貨リスト.

    Returns:
        (DataFrame): このユーザーに推薦する雑貨.

    """    
    global rules_final
    predict_result = pd.DataFrame(None)
    
    for i in range(len(users)):
        user_id = users[i]
        item_list = set(item_list_list[i])

        predict = rules_final[rules_final['antecedents'] <= item_list] ['consequents'].unique()
        # 推薦項目がない 
        if len(predict) == 0:
            continue
            
        predict = set(reduce(lambda x, y: x | y, predict))    
        
        # 推薦項目がない 
        if len(predict) == 0:
            continue
        
        # すでに買った雑貨を削除して推薦しない
        predict_item = predict&item_list
        if len(predict_item) >0:
            for item in predict_item:
                predict.remove(item)
        
        # 推薦項目がない 
        if len(predict) == 0:
            continue
 
        # 推薦項目がある
        predict = pd.DataFrame(list(predict), columns=['item_id'])
        predict = predict.assign(user_id = user_id)
        predict_result = pd.concat([predict_result, predict], axis=0)

    predict_result.reset_index(drop=True, inplace=True)
    return predict_result

# レコメンドリスト作成
prediction = predict(users, item_list_list)

# %%
user_id = 67362
print(f'\nuser_id: {user_id} に対するレコメンドリスト')
prediction[prediction['user_id'] == user_id]
# Out:
# user_id: 67362 に対するレコメンドリスト
#   item_id  user_id
# 6   dairy    67362
